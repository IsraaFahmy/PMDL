# %% [markdown]
# <table align="center">
#   <td align="center"><a target="_blank" href="https://colab.research.google.com/github/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/Lab3.ipynb">
#         <img src="http://introtodeeplearning.com/images/colab/colab.png?v2.0"  style="padding-bottom:5px;" />Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # Lab3: Convolutional Neural Network Use Cases

# %% [markdown]
# ![Simple CNN](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/Cover.png?raw=1)

# %% [markdown]
# ## 3.1 Problem Statement

# %% [markdown]
# In this lab you will build several CNN models that check if a person is happy or not. You will use custom made CNN, and CNN use cases either pretrained or not, also you will apply layers freezing on pretrained CNNs and study all those modifications effect on the accuracy.

# %% [markdown]
# **IMPORTANT NOTE:** You have to change runtime type on Google Colab to GPU since this lab requires much computation resources and it will run very slowly on CPU (Default runtime type)

# %% [markdown]
# ## 3.2 Problem Details

# %% [markdown]
# ### 3.2.1 Packages & Utility Methods

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from tensorflow.keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam, RMSprop, Nadam, Adamax, Adagrad, Adadelta, Ftrl
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.utils import plot_model
from tensorflow.keras import applications
import tensorflow.keras.backend as K
K.set_image_data_format('channels_last')

from IPython.display import SVG
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

import pydot
import h5py
import random
import requests

# %matplotlib inline

# %%
def download_file(file_url):
    file_r = requests.get(file_url, allow_redirects=True)
    open(file_url.rsplit('/', 1)[1], 'wb').write(file_r.content)

# %% [markdown]
# ### 3.2.2 Dataset Loading

# %% [markdown]
# #### Define method to download & load dataset

# %%
def load_dataset():
    download_file("https://raw.githubusercontent.com/KhaledElTahan/DeepLearning/master/Labs/lab3/lab3_train.h5")
    download_file("https://raw.githubusercontent.com/KhaledElTahan/DeepLearning/master/Labs/lab3/lab3_test.h5")

    path_to_train = "lab3_train.h5"
    path_to_test = "lab3_test.h5"

    train_dataset = h5py.File(path_to_train, "r")
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test, "r")
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # reshape y from (samples, ) to (1, samples)
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_x.shape[0]))

    # transpose y
    train_y = train_y.T
    test_y = test_y.T

    return train_x, train_y, test_x, test_y

# %% [markdown]
# #### Define method to make simple preprocessing on the dataset

# %%
def preprocess_data():
    train_x, train_y, test_x, test_y = load_dataset()

    # Normalize image vectors
    train_x = train_x/255.
    test_x = test_x/255.

    print ("number of training examples = " + str(train_x.shape[0]))
    print ("number of test examples = " + str(test_x.shape[0]))

    print ("X_train shape: " + str(train_x.shape))
    print ("Y_train shape: " + str(train_y.shape))
    print ("X_test shape: " + str(test_x.shape))
    print ("Y_test shape: " + str(test_y.shape))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# #### Get the preprocessed Data

# %%
train_x, train_y, test_x, test_y = preprocess_data()
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %% [markdown]
# ### 3.2.3 Dataset Visualization

# %%
W_grid = 6
L_grid = 6

fig, axes = plt.subplots(L_grid, W_grid, figsize = (9,9))

axes = axes.ravel() # flaten the L_grid x W_grid matrix into L_grid * W_grid array

n_training = len(train_x) # get the length of the training dataset

for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    index = np.random.randint(0, n_training)
    axes[i].imshow(train_x[index])

    if train_y[index] == 1:
        axes[i].set_title("Happy", fontsize = 10)
    else:
        axes[i].set_title("Not Happy", fontsize = 10)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ### 3.2.4 Plot Utility Methods

# %% [markdown]
# The following code is used to plot accuracy and loss histories for each model experiment.

# %%
def plot(training_results, validation_results, results_type, model_name):
    fig = plt.figure(figsize=[8, 6])

    plt.plot(training_results, 'r', linewidth=3.0)
    plt.plot(validation_results, 'b', linewidth=3.0)
    plt.legend(['Training ' + results_type, 'Validation ' + results_type], fontsize=18)
    plt.xlabel('Epochs', fontsize=16)
    plt.ylabel(results_type, fontsize=16)
    plt.title(results_type + ' of ' + model_name, fontsize=16)


def plot_accuracy(history, model_name):
    plot(history.history['accuracy'], history.history['val_accuracy'], 'Accuracy', model_name)
    

def plot_loss(history, model_name):
    plot(history.history['loss'], history.history['val_loss'], 'Loss', model_name)

# %% [markdown]
# ### 3.2.5 Custom CNN Model

# %% [markdown]
# **TODO**: Build a custom CNN model to solve the problem.
#
# Model guidelines (You need to follow them):
#
# 1. [Input](https://keras.io/api/layers/core_layers/input/) Layer.
# 2. [ZeroPadding2D](https://keras.io/api/layers/reshaping_layers/zero_padding2d/) Layer.
# 3. [Conv2D](https://keras.io/api/layers/convolution_layers/convolution2d/) Layer.
# 4. [BatchNormalization](https://keras.io/api/layers/normalization_layers/batch_normalization/) Layer. Read [this article](https://kharshit.github.io/blog/2018/12/28/why-batch-normalization) for more about Batchnormalization.
# 5. Relu [Activation](https://keras.io/api/layers/core_layers/activation/).
# 6. [MaxPooling2D](https://keras.io/api/layers/pooling_layers/max_pooling2d/) Layer.
# 7. [Flatten](https://keras.io/api/layers/reshaping_layers/flatten/) Layer.
# 8. [Dense](https://keras.io/api/layers/core_layers/dense/) with Sigmoid Layer (one perceptrion).
#
# **Note**: If you made the required model, you can make other custom CNN models if you wish to further improve the accuracy, but in other code cells however.

# %%
def CustomCNN(input_shape):
    """
    Implementation of the Custom CNN.
    Args:
        input_shape () shape of the images of the dataset
    Returns:
        model (Keras.Model): CNN Custom Model
        model_name (Str): The name of the model
    """
    
    ### START CODE HERE ###
    X_input = Input(input_shape)

    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((3, 3))(X_input)

    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization(axis=3, name='bn0')(X)
    X = Activation('relu')(X)

    # MAXPOOL
    X = MaxPooling2D((2, 2), name='max_pool')(X)

    # FLATTEN X (means convert it to a vector) + FULLYCONNECTED (Dense)
    X = Flatten()(X)
    X = Dense(1, activation='sigmoid', name='fc')(X)

    # Create model. This creates your tensorflow.keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs=X_input, outputs=X)
    ### END CODE HERE ###
    
    return model, "Custom CNN"

# %% [markdown]
# ### 3.2.6 CNN Use Case No.1: VGG

# %% [markdown]
# ![VGG Architecture](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/vgg.png?raw=1)

# %% [markdown]
# **Note**: this ia a show case to help you do the same with other use cases.
#
# **TODO**: Try different variations for VGG:
#
# 1. [VGG16](https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG16)
# 2. [VGG19](https://www.tensorflow.org/api_docs/python/tf/keras/applications/VGG19)
#
# **Note**: You will need to experiment all of them both pretrained and untrained.

# %%
def VGG(pretrained = True, input_shape = (64, 64, 3), model_name = "VGG19"):
    """
    Returns VGG Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        VGG(True) -> Model, "Pretrained VGG16"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        base_model = applications.vgg19.VGG19(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        base_model = applications.vgg19.VGG19(weights=None, include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.7 CNN Use Case No.2: ResNet

# %% [markdown]
# ![VGG vs ResNet](https://github.com/KhaledElTahan/DeepLearning/blob/master/Labs/lab3/VGG_vs_ResNet.png?raw=1)

# %% [markdown]
# **TODO**: Follow the same style for the above mentioned VGG and experiment the following ResNets:
#
# 1. [ResNet50](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet50)
# 2. [ResNet50V2](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet50V2)
# 3. [ResNet101](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet101)
# 4. [ResNet101v2](https://www.tensorflow.org/api_docs/python/tf/keras/applications/ResNet101V2)
#
# **Note**: You will need to experiment all of them both pretrained and untrained.

# %%
def ResNet(pretrained = True, input_shape = (64, 64, 3), model_name = "ResNet101"):
    """
    Returns ResNet Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        ResNet(True) -> Model, "Pretrained ResNet50"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        base_model = applications.resnet.ResNet101(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        base_model =applications.resnet.ResNet101(weights=None, include_top=False, input_shape=input_shape, pooling='none')


    return base_model, model_name

# %% [markdown]
# ### 3.2.8 CNN Use Case No.3: Your choice

# %% [markdown]
# **TODO**: Select one application other than VGG or ResNet from [here](https://www.tensorflow.org/api_docs/python/tf/keras/applications) and implement it the same way you did with VGG & ResNet.

# %%
def CNN_App(pretrained = True, input_shape = (64, 64, 3), model_name = "EfficientNetB7"):
    """
    Returns A Custom CNN Application Keras Model
    Args:
        pretrained (Bool): Whether get a pretrained model or not
        input_shape (Tuple): To create the input layer, should match the image resolution
        model_name (str): String to capture the model name
    Examples:
        CNN_App(True, (64, 64, 3), "Xception") -> Model, "Pretrained Xception"
    """
    if(pretrained):
        model_name = "Pretrained " + model_name
        base_model =  applications.EfficientNetB7(weights='imagenet', include_top=False, input_shape=input_shape, pooling='none')
    else:
        model_name = "Untrained " + model_name
        base_model = applications.EfficientNetB7(weights=None , include_top=False, input_shape=input_shape, pooling='none')

    return base_model, model_name

# %% [markdown]
# ### 3.2.9 Layers Freezing

# %% [markdown]
# The following utility method is used for layers freezing.

# %% [markdown]
# **TODO**: Experiment all the pretrained models with layers freezing using different number of freezed layers.
#
# **NOTE**: You will not change this method at all, the experimenting will take place in the test cases section below.

# %%
def freeze(model, number_of_freezed_layers):
    layers = model.layers

    layers = layers[:number_of_freezed_layers]

    for layer in layers:
        layer.trainable = False

    return model

# %% [markdown]
# ### 3.2.10 Make your models

# %% [markdown]
# Use the following utility method to make the model you desire.

# %%
def make_model(pretrained=True, freeze_layers=False, number_of_freezed_layers=0, model_selection="VGG"):
    """
    Use this method to create models
    Args:
      pretrained (Bool): Whether make the model pretrained or not, doesn't apply to custom CNN.
      freeze_layers (Bool): Whether apply layers freezing on pretrained networks or not.
      number_of_freezed_layers (int): Number of frozen layers.
      model_selection (Str): Must be exactly "Custom", or "VGG", or "ResNet" or anything else for CNN_App
    """

    input_shape = (64, 64, 3)

    if model_selection == "Custom":
        model, model_name = CustomCNN(input_shape)
    elif model_selection == "VGG":
        model, model_name = VGG(pretrained, input_shape)
    elif model_selection == "ResNet":
        model, model_name = ResNet(pretrained, input_shape)
    else:
        model, model_name = CNN_App(pretrained, input_shape)

    if model_selection != "Custom":
        if freeze_layers:
            model = freeze(model, number_of_freezed_layers)
            model_name = model_name + " with " + str(number_of_freezed_layers) + " Frozen Layers"

        ## Add classification head for non custom models
        y = model.output
        y = Flatten()(y)
        y = Dense(256, activation='relu')(y)
        y = Dense(1, activation='sigmoid', name='fc')(y)

        model = Model(inputs=model.input, outputs=y)

    return model, model_name

# %% [markdown]
# ### 3.2.11 Testing model utility method

# %% [markdown]
# This is a generic method that will be used to test all the implemented models, a modular design allows you to experiment more clearly.

# %% [markdown]
# **TODO**:
#
# 1. Try different [optimizers](https://keras.io/api/optimizers/) and report their affect on the **results** and plots.
# 2. For each optimizer, try different learning rates and other hyperparameters (If applicable), and report the difference on the **results** and plots.
# 3. Try different [loss functions](https://keras.io/api/losses/), and report their affect on **accuracy** and plots.

# %%
def test_model(model, model_name, epochs=10, print_summary=True, plot_results=True):
    '''TODO: Experiment with different optimizers, learning rates, and losses'''

    sgd = SGD(lr=0.0001, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])

    if (print_summary):
        model.summary()

    hist = model.fit(train_x, train_y, validation_data = (test_x, test_y), verbose=1, epochs=epochs, batch_size=32)
    preds = model.evaluate(test_x, test_y, batch_size=32, verbose=1, sample_weight=None)

    print ("Validation Loss = " + str(preds[0]))
    print ("Validation Accuracy = " + str(preds[1]))

    if(plot_results):
        plot_loss(hist, model_name)
        plot_accuracy(hist, model_name)

# %% [markdown]
# ### 3.2.12 Create your model test cases.

# %% [markdown]
# **TODO**: Fill here all the test cases methods that you want to apply.
#
# Add methods (Untrained, pretrained & pretrained with freezing) for:
# 1. ResNet
# 2. CNN App
#
# **NOTE**: Those test cases, don't change use case types (i.e. you will need to change the VGG in VGG() method to VGG19 and re test again for example) and doesn't change the loss function nor the optimizer type.

# %% [markdown]
# **Custom CNN** test cases

# %%
def test_custom_CNN(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "Custom")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %% [markdown]
# **VGG** test cases

# %%
def test_untrained_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_VGG(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, 10, "VGG")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %% [markdown]
# **ResNet** test cases

# %%
def test_untrained_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_ResNet(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, 10, "ResNet")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %% [markdown]
# **CNN App** test cases

# %%
def test_untrained_EfficientNetB(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(False, False, 0, "EfficientNetB7")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_EfficientNetB(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, False, 0, "EfficientNetB7")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %%
def test_pretrained_layers_freezing_EfficientNetB(epochs=20, print_summary=True, plot_results=True):
    model, model_name = make_model(True, True, 10, "EfficientNetB7")
    test_model(model, model_name, epochs, print_summary, plot_results)

# %% [markdown]
# ###  3.2.13 Test your models

# %% [markdown]
# **TODO**: Call all your defined methods for testing here.
#
# **Note**: You might want to go up to 1000 epochs for the untrained model if the validation accuracy is low.

# %%
test_custom_CNN(20)
# Out:
# Model: "model_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_72 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# zero_padding2d_33 (ZeroPaddi (None, 70, 70, 3)         0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 64, 64, 32)        4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 64, 64, 32)        128
# _________________________________________________________________
# activation_221 (Activation)  (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pool (MaxPooling2D)      (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_71 (Flatten)         (None, 32768)             0
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 32769
# =================================================================
# Total params: 37,633
# Trainable params: 37,569
# Non-trainable params: 64
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 1s 21ms/step - loss: 0.7841 - accuracy: 0.4997 - val_loss: 0.6820 - val_accuracy: 0.6067
# Epoch 2/20
# 19/19 [==============================] - 0s 13ms/step - loss: 0.5062 - accuracy: 0.7419 - val_loss: 0.6562 - val_accuracy: 0.6467
# Epoch 3/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.3648 - accuracy: 0.8780 - val_loss: 0.6304 - val_accuracy: 0.7533
# Epoch 4/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.3140 - accuracy: 0.8914 - val_loss: 0.6069 - val_accuracy: 0.8600
# Epoch 5/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.2669 - accuracy: 0.9263 - val_loss: 0.5835 - val_accuracy: 0.8933
# Epoch 6/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.2363 - accuracy: 0.9333 - val_loss: 0.5623 - val_accuracy: 0.9133
# Epoch 7/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.2313 - accuracy: 0.9420 - val_loss: 0.5417 - val_accuracy: 0.9333
# Epoch 8/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1996 - accuracy: 0.9564 - val_loss: 0.5210 - val_accuracy: 0.9267
# Epoch 9/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1758 - accuracy: 0.9642 - val_loss: 0.5019 - val_accuracy: 0.9400
# Epoch 10/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1696 - accuracy: 0.9563 - val_loss: 0.4820 - val_accuracy: 0.9400
# Epoch 11/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1589 - accuracy: 0.9657 - val_loss: 0.4601 - val_accuracy: 0.9267
# Epoch 12/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1653 - accuracy: 0.9540 - val_loss: 0.4384 - val_accuracy: 0.9467
# Epoch 13/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1544 - accuracy: 0.9667 - val_loss: 0.4184 - val_accuracy: 0.9467
# Epoch 14/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1386 - accuracy: 0.9611 - val_loss: 0.3975 - val_accuracy: 0.9400
# Epoch 15/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1342 - accuracy: 0.9661 - val_loss: 0.3775 - val_accuracy: 0.9333
# Epoch 16/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1567 - accuracy: 0.9555 - val_loss: 0.3585 - val_accuracy: 0.9467
# Epoch 17/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.1189 - accuracy: 0.9806 - val_loss: 0.3397 - val_accuracy: 0.9333
# Epoch 18/20
# 19/19 [==============================] - 0s 11ms/step - loss: 0.
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0185 - accuracy: 0.9990 - val_loss: 0.0706 - val_accuracy: 0.9800
# Epoch 19/20
# 19/19 [==============================] - 1s 55ms/step - loss: 0.0254 - accuracy: 0.9944 - val_loss: 0.0679 - val_accuracy: 0.9733
# Epoch 20/20
# 19/19 [==============================] - 1s 54ms/step - loss: 0.0212 - accuracy: 0.9989 - val_loss: 0.0747 - val_accuracy: 0.9733
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0747 - accuracy: 0.9733
# Validation Loss = 0.07466822862625122
# Validation Accuracy = 0.9733333587646484

# %%
test_pretrained_layers_freezing_VGG(20)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "model_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_37 (InputLayer)        [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_36 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               524544
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 257
# =================================================================
# Total params: 20,549,185
# Trainable params: 18,813,697
# Non-trainable params: 1,735,488
# _________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 2s 62ms/step - loss: 0.7438 - accuracy: 0.5437 - val_loss: 0.6413 - val_accuracy: 0.5667
# Epoch 2/20
# 19/19 [==============================] - 1s 47ms/step - loss: 0.6327 - accuracy: 0.6882 - val_loss: 0.5854 - val_accuracy: 0.7800
# Epoch 3/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.5432 - accuracy: 0.8585 - val_loss: 0.5135 - val_accuracy: 0.8400
# Epoch 4/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.4817 - accuracy: 0.8957 - val_loss: 0.4527 - val_accuracy: 0.8667
# Epoch 5/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.3928 - accuracy: 0.9234 - val_loss: 0.3921 - val_accuracy: 0.8867
# Epoch 6/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.3246 - accuracy: 0.9384 - val_loss: 0.3261 - val_accuracy: 0.9200
# Epoch 7/20
# 19/19 [==============================] - 1s 49ms/step - loss: 0.2628 - accuracy: 0.9423 - val_loss: 0.2719 - val_accuracy: 0.9333
# Epoch 8/20
# 19/19 [==============================] - 1s 49ms/step - loss: 0.2168 - accuracy: 0.9602 - val_loss: 0.2729 - val_accuracy: 0.8733
# Epoch 9/20
# 19/19 [==============================] - 1s 49ms/step - loss: 0.1731 - accuracy: 0.9563 - val_loss: 0.1809 - val_accuracy: 0.9600
# Epoch 10/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.1556 - accuracy: 0.9438 - val_loss: 0.2012 - val_accuracy: 0.9333
# Epoch 11/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.1233 - accuracy: 0.9713 - val_loss: 0.1307 - val_accuracy: 0.9733
# Epoch 12/20
# 19/19 [==============================] - 1s 48ms/step - loss: 0.1107 - accuracy: 0.9761 - val_loss: 0.1140 - val_accuracy: 0.9667
preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block10_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block10_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Add)         (None, 4, 4, 1024)   0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block11_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block11_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block11_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Add)         (None, 4, 4, 1024)   0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block12_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block12_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block12_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Add)         (None, 4, 4, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_preact_relu (Acti (None, 4, 4, 1024)   0           conv4_block13_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 4, 4, 256)    262144      conv4_block13_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_pad (ZeroPaddin (None, 6, 6, 256)    0           conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 4, 4, 256)    589824      conv4_block13_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Add)         (None, 4, 4, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_preact_bn (BatchN (None, 4, 4, 1024)   4096        conv4_block13_out[0][0]
# ...
# Epoch 92/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0084 - accuracy: 0.9991 - val_loss: 0.1104 - val_accuracy: 0.9667
# Epoch 93/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 0.1024 - val_accuracy: 0.9600
# Epoch 94/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0249 - accuracy: 0.9910 - val_loss: 0.1110 - val_accuracy: 0.9533
# Epoch 95/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 0.9733
# Epoch 96/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0134 - accuracy: 0.9986 - val_loss: 0.1036 - val_accuracy: 0.9667
# Epoch 97/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9600
# Epoch 98/200
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0076 - accuracy: 0.9996 - val_loss: 0.1351 - val_accuracy: 0.9600
# Epoch 99/200
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0166 - accuracy: 0.9969 - val_loss: 0.1274 - val_accuracy: 0.9467
# Epoch 100/200
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0067 - accuracy: 0.9998 - val_loss: 0.1252 - val_accuracy: 0.9533
# Epoch 101/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 0.9600
# Epoch 102/200
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0
3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Activation)  (None, 4, 4, 1024)   0           conv4_block11_add[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_add (Add)         (None, 4, 4, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Activation)  (None, 4, 4, 1024)   0           conv4_block12_add[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_add (Add)         (None, 4, 4, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Activation)  (None, 4, 4, 1024)   0           conv4_block13_add[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block13_out[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block14_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block14_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block14_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_add (Add)         (None, 4, 4, 1024)   0           conv4_block13_out[0][0]
#                                                                  conv4_block14_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_out (Activation)  (None, 4, 4, 1024)   0           conv4_block14_add[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block14_out[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block15_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block15_2_relu[0][0]
# __________________________________________________________________________________________________
# ...
# conv4_block21_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block21_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block21_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block21_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block21_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block21_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block21_add (Add)         (None, 4, 4, 1024)   0           conv4_block20_out[0][0]
#                                                                  conv4_block21_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block21_out (Activation)  (None, 4, 4, 1024)   0           conv4_block21_add[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block21_out[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block22_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block22_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block22_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block22_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block22_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block22_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block22_add (Add)         (None, 4, 4, 1024)   0           conv4_block21_out[0][0]
#                                                                  conv4_block22_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block22_out (Activation)  (None, 4, 4, 1024)   0           conv4_block22_add[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block22_out[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block23_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block23_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block23_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block23_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block23_add (Add)         (None, 4, 4, 1024)   0           conv4_block22_out[0][0]
#                                                                  conv4_block23_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block23_out (Activation)  (None, 4, 4, 1024)   0           conv4_block23_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    524800      conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 2, 2, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 2, 2, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 2048)   2099200     conv4_block23_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 2, 2, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 2, 2, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 2, 2, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 2, 2, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 2, 2, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 2, 2, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 2, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 2, 2, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 2, 2, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 2, 2, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 2, 2, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten_66 (Flatten)            (None, 8192)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 256)          2097408     flatten_66[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_37[0][0]
# ==================================================================================================
# Total params: 44,755,841
# Trainable params: 44,650,497
# Non-trainable params: 105,344
# __________________________________________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 13s 207ms/step - loss: 0.7075 - accuracy: 0.6229 - val_loss: 1.4327 - val_accuracy: 0.5600
# Epoch 2/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.2301 - accuracy: 0.9209 - val_loss: 9.6224 - val_accuracy: 0.5600
# Epoch 3/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.1235 - accuracy: 0.9756 - val_loss: 13.6155 - val_accuracy: 0.5600
# Epoch 4/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0807 - accuracy: 0.9860 - val_loss: 26.5746 - val_accuracy: 0.5600
# Epoch 5/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0584 - accuracy: 0.9911 - val_loss: 45.2846 - val_accuracy: 0.5600
# Epoch 6/20
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0436 - accuracy: 0.9976 - val_loss: 75.8517 - val_accuracy: 0.5600
# Epoch 7/20
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0362 - accuracy: 0.9966 - val_loss: 123.3266 - val_accuracy: 0.5600
# Epoch 8/20
# 19/19 [==============================] - 2s 113ms/step - loss: 0.0285 - accuracy: 0.9987 - val_loss: 178.9322 - val_accuracy: 0.5600
# Epoch 9/20
# 19/19 [==============================] - 2s 112ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 242.2528 - val_accuracy: 0.5600
# Epoch 10/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0292 - accuracy: 0.9988 - val_loss: 328.4112 - val_accuracy: 0.5600
# Epoch 11/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0182 - accuracy: 0.9982 - val_loss: 432.8867 - val_accuracy: 0.5600
# Epoch 12/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0297 - accuracy: 0.9957 - val_loss: 544.0945 - val_accuracy: 0.5600
# Epoch 13/20
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 596.0800 - val_accuracy: 0.5600
# Epoch 14/20
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0128 - accuracy: 0.9993 - val_loss: 656.4334 - val_accuracy: 0.5600
# Epoch 15/20
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss:
3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_out (Activation)   (None, 4, 4, 1024)   0           conv4_block7_add[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block7_out[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 4, 4, 256)    0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_relu (Activation (None, 4, 4, 256)    0           conv4_block8_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block8_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block8_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_add (Add)          (None, 4, 4, 1024)   0           conv4_block7_out[0][0]
#                                                                  conv4_block8_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_out (Activation)   (None, 4, 4, 1024)   0           conv4_block8_add[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block8_out[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 4, 4, 256)    0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_relu (Activation (None, 4, 4, 256)    0           conv4_block9_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block9_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block9_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_add (Add)          (None, 4, 4, 1024)   0           conv4_block8_out[0][0]
#                                                                  conv4_block9_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_out (Activation)   (None, 4, 4, 1024)   0           conv4_block9_add[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block9_out[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block10_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block10_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block10_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_add (Add)         (None, 4, 4, 1024)   0           conv4_block9_out[0][0]
#                                                                  conv4_block10_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_out (Activation)  (None, 4, 4, 1024)   0           conv4_block10_add[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block10_out[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block11_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block11_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block11_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_add (Add)         (None, 4, 4, 1024)   0           conv4_block10_out[0][0]
#                                                                  conv4_block11_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_out (Activation)  (None, 4, 4, 1024)   0           conv4_block11_add[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block11_out[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block12_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block12_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block12_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_add (Add)         (None, 4, 4, 1024)   0           conv4_block11_out[0][0]
#                                                                  conv4_block12_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_out (Activation)  (None, 4, 4, 1024)   0           conv4_block12_add[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block12_out[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block13_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block13_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block13_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block13_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_add (Add)         (None, 4, 4, 1024)   0           conv4_block12_out[0][0]
#                                                                  conv4_block13_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block13_out (Activation)  (None, 4, 4, 1024)   0           conv4_block13_add[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block13_out[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block14_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_conv (Conv2D)   (None, 4, 4, 1024)   263168      conv4_block14_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block14_3_bn (BatchNormal (None, 4, 4, 1024)   4096        conv4_block14_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block14_add (Add)         (None, 4, 4, 1024)   0           conv4_block13_out[0][0]
#                                                                  conv4_block14_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block14_out (Activation)  (None, 4, 4, 1024)   0           conv4_block14_add[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_conv (Conv2D)   (None, 4, 4, 256)    262400      conv4_block14_out[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_1_relu (Activatio (None, 4, 4, 256)    0           conv4_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_conv (Conv2D)   (None, 4, 4, 256)    590080      conv4_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_bn (BatchNormal (None, 4, 4, 256)    1024        conv4_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block15_2_relu (Activatio (None, 4, 4, 256)    0           conv4_block15_2_bn[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 2, 2, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 2, 2, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten_40 (Flatten)            (None, 8192)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 256)          2097408     flatten_40[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_36[0][0]
# ==================================================================================================
# Total params: 44,755,841
# Trainable params: 44,636,609
# Non-trainable params: 119,232
# __________________________________________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 12s 200ms/step - loss: 0.9037 - accuracy: 0.5770 - val_loss: 0.7786 - val_accuracy: 0.5600
# Epoch 2/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.2540 - accuracy: 0.9161 - val_loss: 0.8075 - val_accuracy: 0.5600
# Epoch 3/100
# 19/19 [==============================] - 2s 106ms/step - loss: 0.1274 - accuracy: 0.9770 - val_loss: 0.7219 - val_accuracy: 0.5600
# Epoch 4/100
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0944 - accuracy: 0.9811 - val_loss: 1.2203 - val_accuracy: 0.4400
# Epoch 5/100
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0721 - accuracy: 0.9916 - val_loss: 1.2499 - val_accuracy: 0.4400
# Epoch 6/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0644 - accuracy: 0.9874 - val_loss: 2.1804 - val_accuracy: 0.4400
# Epoch 7/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0481 - accuracy: 0.9929 - val_loss: 4.4442 - val_accuracy: 0.4400
# Epoch 8/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0383 - accuracy: 0.9955 - val_loss: 3.2047 - val_accuracy: 0.4400
# Epoch 9/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0311 - accuracy: 0.9952 - val_loss: 2.9087 - val_accuracy: 0.4400
# Epoch 10/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0309 - accuracy: 0.9912 - val_loss: 3.0891 - val_accuracy: 0.4400
# Epoch 11/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0291 - accuracy: 0.9963 - val_loss: 2.9569 - val_accuracy: 0.4400
# Epoch 12/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0240 - accuracy: 0.9988 - val_loss: 1.9669 - val_accuracy: 0.4400
# Epoch 13/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0213 - accuracy: 0.9968 - val_loss: 0.9768 - val_accuracy: 0.4400
# Epoch 14/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0140 - accuracy: 0.9984 - val_loss: 0.6637 - val_accuracy: 0.6267
# Epoch 15/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0151 - accuracy: 0.9991 - val_loss: 0.8679 - val_accuracy: 0.5600
# Epoch 16/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0144 - accuracy: 0.9988 - val_loss: 1.8819 - val_accuracy: 0.5600
# Epoch 17/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.
ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.3514 - val_accuracy: 0.5733
# Epoch 43/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.0992 - val_accuracy: 0.5933
# Epoch 44/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.9625 - val_accuracy: 0.5600
# Epoch 45/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.9256 - val_accuracy: 0.5733
# Epoch 46/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.9147 - val_accuracy: 0.4933
# Epoch 47/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.5133
# Epoch 48/100
# 19/19 [==============================] - 3s 135ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7644 - val_accuracy: 0.5600
# Epoch 49/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.7315 - val_accuracy: 0.5933
# Epoch 50/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.7749 - val_accuracy: 0.6200
# Epoch 51/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7107 - val_accuracy: 0.6200
# Epoch 52/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6654 - val_accuracy: 0.6733
# Epoch 53/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6465 - val_accuracy: 0.6733
# Epoch 54/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6554 - val_accuracy: 0.7067
# Epoch 55/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0051 - accuracy: 0.9976 - val_loss: 0.7102 - val_accuracy: 0.6867
# Epoch 56/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5732 - val_accuracy: 0.7400
# Epoch 57/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.4354 - val_accuracy: 0.7867
# Epoch 58/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3282 - val_accuracy: 0.8533
# Epoch 59/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2915 - val_accuracy: 0.8933
# Epoch 60/100
# 19/19 [==============================] - 2s 106ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3385 - val_accuracy: 0.8867
# Epoch 61/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0062 - accuracy: 0.9988 - val_loss: 0.2035 - val_accuracy: 0.9133
# Epoch 62/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2111 - val_accuracy: 0.9133
# Epoch 63/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9267
# Epoch 64/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9200
# Epoch 65/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1342 - val_accuracy: 0.9467
# Epoch 66/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0982 - val_accuracy: 0.9600
# Epoch 67/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.9400
# Epoch 68/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9400
# Epoch 69/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1240 - val_accuracy: 0.9600
# Epoch 70/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9667
# Epoch 71/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 0.9733
# Epoch 72/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 0.9800
# Epoch 73/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0461 - val_accuracy: 0.9933
# Epoch 74/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9600
# Epoch 75/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0532 - val_accuracy: 0.9800
# Epoch 76/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9933
# Epoch 77/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0914 - val_accuracy: 0.9733
# Epoch 78/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9667
# Epoch 79/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9667
# Epoch 80/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 0.9733
# Epoch 81/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9867
# Epoch 82/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 0.9867
# Epoch 83/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9733
# Epoch 84/100
# 19/19 [==============================] - 2s 107ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 0.9867
# Epoch 85/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 7.9444 - val_accuracy: 0.5533
# Epoch 86/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 16.3078 - val_accuracy: 0.4600
# Epoch 87/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0182 - accuracy: 0.9953 - val_loss: 4.2539 - val_accuracy: 0.5400
# Epoch 88/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0156 - accuracy: 0.9972 - val_loss: 3.7869 - val_accuracy: 0.6000
# Epoch 89/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0139 - accuracy: 0.9997 - val_loss: 1.5046 - val_accuracy: 0.5467
# Epoch 90/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0066 - accuracy: 0.9986 - val_loss: 2.2637 - val_accuracy: 0.5600
# Epoch 91/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0066 - accuracy: 0.9991 - val_loss: 1.9971 - val_accuracy: 0.5600
# Epoch 92/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.6978 - val_accuracy: 0.5600
# Epoch 93/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.1823 - val_accuracy: 0.5600
# Epoch 94/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 2.2712 - val_accuracy: 0.5733
# Epoch 95/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.8092 - val_accuracy: 0.5733
# Epoch 96/100
# 19/19 [==============================] - 2s 108ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 1.2693 - val_accuracy: 0.6467
# Epoch 97/100
# 19/19 [==============================] - 2s 109ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 0.7202 - val_accuracy: 0.7533
# Epoch 98/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.8467
# Epoch 99/100
# 19/19 [==============================] - 2s 111ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.9000
# Epoch 100/100
# 19/19 [==============================] - 2s 110ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2508 - val_accuracy: 0.9133
# 5/5 [==============================] - 0s 31ms/step - loss: 0.2508 - accuracy: 0.9133
# Validation Loss = 0.25078141689300537
# Validation Accuracy = 0.9133333563804626

# %% [markdown]
# **Testing Inception_v3 model**

# %%
test_untrained_EfficientNetB(300)
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_3 (Rescaling)         (None, 64, 64, 3)    0           input_20[0][0]
# __________________________________________________________________________________________________
# normalization_3 (Normalization) (None, 64, 64, 3)    7           rescaling_3[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 65, 65, 3)    0           normalization_3[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 32, 32, 64)   1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 32, 32, 64)   256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 32, 32, 64)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 32, 32, 64)   576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 32, 32, 64)   256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 32, 32, 64)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 32, 32, 64)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 32, 32, 32)   2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 32, 32, 32)   128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 32, 32, 32)   128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 32, 32, 32)   0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 32, 32, 32)   0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 32, 32, 32)   128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 32, 32, 32)   0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 32, 32, 32)   0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 32, 32, 32)   128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 32, 32, 32)   0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 32, 32, 32)   0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 32, 32, 32)   128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 32, 32, 32)   0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 32, 32, 32)   0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 32, 32, 32)   128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 32, 32, 32)   0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 32, 32, 32)   0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 32, 32, 32)   128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 32, 32, 32)   0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 32, 32, 32)   0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 32, 32, 192)  6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 32, 32, 192)  768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 32, 32, 192)  0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 33, 33, 192)  0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 16, 16, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 16, 16, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 16, 16, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 16, 16, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 16, 16, 48)   9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 16, 16, 48)   192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 16, 16, 288)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 16, 16, 288)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 16, 16, 288)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 16, 16, 48)   192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 16, 16, 48)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 16, 16, 48)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 16, 16, 288)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 16, 16, 288)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 16, 16, 288)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 16, 16, 48)   192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 16, 16, 48)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 16, 16, 48)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 16, 16, 288)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 16, 16, 288)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 16, 16, 288)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 16, 16, 48)   192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 16, 16, 48)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 16, 16, 48)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 16, 16, 288)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 16, 16, 288)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 16, 16, 288)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 16, 16, 48)   192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 16, 16, 48)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 16, 16, 48)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 16, 16, 288)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 16, 16, 288)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 16, 16, 288)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 16, 16, 48)   192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 16, 16, 48)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 16, 16, 48)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 16, 16, 288)  0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 16, 16, 288)  0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 16, 16, 288)  0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 16, 16, 48)   192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 16, 16, 48)   0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 16, 16, 48)   0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 16, 16, 288)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 19, 19, 288)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 8, 8, 288)    7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 8, 8, 288)    1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 8, 8, 288)    0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 8, 8, 288)    0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 8, 8, 80)     23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 8, 8, 80)     320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 8, 8, 480)    0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 8, 8, 480)    0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 8, 8, 480)    0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 8, 8, 80)     320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 8, 8, 80)     0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 8, 8, 80)     0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 8, 8, 480)    0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 8, 8, 480)    0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 8, 8, 480)    0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 8, 8, 80)     320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 8, 8, 80)     0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 8, 8, 80)     0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 8, 8, 480)    0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 8, 8, 480)    0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 8, 8, 480)    0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 8, 8, 80)     320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 8, 8, 80)     0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 8, 8, 80)     0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 8, 8, 480)    0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 8, 8, 480)    0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 8, 8, 480)    0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# Epoch 192/300
# 19/19 [==============================] - 5s 251ms/step - loss: 0.2385 - accuracy: 0.9187 - val_loss: 0.4039 - val_accuracy: 0.9000
# Epoch 193/300
# 19/19 [==============================] - 5s 248ms/step - loss: 0.1802 - accuracy: 0.9290 - val_loss: 0.3481 - val_accuracy: 0.9200
# Epoch 194/300
# 19/19 [==============================] - 5s 249ms/step - loss: 0.2152 - accuracy: 0.8927 - val_loss: 0.5428 - val_accuracy: 0.8933
# Epoch 195/300
# 19/19 [==============================] - 5s 250ms/step - loss: 0.1983 - accuracy: 0.9131 - val_loss: 0.7894 - val_accuracy: 0.9000
# Epoch 196/300
# 19/19 [==============================] - 5s 251ms/step - loss: 0.2121 - accuracy: 0.9039 - val_loss: 0.4083 - val_accuracy: 0.9000
# Epoch 197/300
# 19/19 [==============================] - 5s 250ms/step - loss: 0.1556 - accuracy: 0.9442 - val_loss: 0.3472 - val_accuracy: 0.9133
# Epoch 296/300
# 19/19 [==============================] - 5s 253ms/step - loss: 0.1490 - accuracy: 0.9454 - val_loss: 0.2125 - val_accuracy: 0.9200
# Epoch 297/300
# 19/19 [==============================] - 5s 249ms/step - loss: 0.1610 - accuracy: 0.9326 - val_loss: 0.3082 - val_accuracy: 0.9200
# Epoch 298/300
# 19/19 [==============================] - 5s 249ms/step - loss: 0.1182 - accuracy: 0.9464 - val_loss: 0.3150 - val_accuracy: 0.9133
# Epoch 299/300
# 19/19 [==============================] - 5s 253ms/step - loss: 0.1621 - accuracy: 0.9197 - val_loss: 0.2319 - val_accuracy: 0.9267
# Epoch 300/300
# 19/19 [==============================] - 5s 247ms/step - loss: 0.1686 - accuracy: 0.9334 - val_loss: 0.2780 - val_accuracy: 0.9133
# 5/5 [==============================] - 0s 64ms/step - loss: 0.2780 - accuracy: 0.9133
# Validation Loss = 0.27802127599716187
# Validation Accuracy = 0.9133333563804626

# %%
test_pretrained_EfficientNetB(20)
# Out:
# Model: "model_70"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_74 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_9 (Rescaling)         (None, 64, 64, 3)    0           input_74[0][0]
# __________________________________________________________________________________________________
# normalization_9 (Normalization) (None, 64, 64, 3)    7           rescaling_9[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 65, 65, 3)    0           normalization_9[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 32, 32, 64)   1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 32, 32, 64)   256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 32, 32, 64)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 32, 32, 64)   576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 32, 32, 64)   256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 32, 32, 64)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 32, 32, 64)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 32, 32, 32)   2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 32, 32, 32)   128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 32, 32, 32)   128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 32, 32, 32)   0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 32, 32, 32)   0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 32, 32, 32)   128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 32, 32, 32)   0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 32, 32, 32)   0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 32, 32, 32)   128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 32, 32, 32)   0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 32, 32, 32)   0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 32, 32, 32)   128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 32, 32, 32)   0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 32, 32, 32)   0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 32, 32, 32)   128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 32, 32, 32)   0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 32, 32, 32)   0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 32, 32, 32)   128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 32, 32, 32)   0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 32, 32, 32)   0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 32, 32, 192)  6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 32, 32, 192)  768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 32, 32, 192)  0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 33, 33, 192)  0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 16, 16, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 16, 16, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 16, 16, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 16, 16, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 16, 16, 48)   9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 16, 16, 48)   192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 16, 16, 288)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 16, 16, 288)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 16, 16, 288)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 16, 16, 48)   192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 16, 16, 48)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 16, 16, 48)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 16, 16, 288)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 16, 16, 288)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 16, 16, 288)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 16, 16, 48)   192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 16, 16, 48)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 16, 16, 48)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 16, 16, 288)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 16, 16, 288)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 16, 16, 288)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 16, 16, 48)   192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 16, 16, 48)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 16, 16, 48)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 16, 16, 288)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 16, 16, 288)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 16, 16, 288)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 16, 16, 48)   192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 16, 16, 48)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 16, 16, 48)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 16, 16, 288)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 16, 16, 288)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 16, 16, 288)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 16, 16, 48)   192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 16, 16, 48)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 16, 16, 48)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 16, 16, 288)  0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 16, 16, 288)  0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 16, 16, 288)  0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 16, 16, 48)   192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 16, 16, 48)   0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 16, 16, 48)   0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 16, 16, 288)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 19, 19, 288)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 8, 8, 288)    7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 8, 8, 288)    1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 8, 8, 288)    0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 8, 8, 288)    0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 8, 8, 80)     23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 8, 8, 80)     320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 8, 8, 480)    0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 8, 8, 480)    0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 8, 8, 480)    0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 8, 8, 80)     320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 8, 8, 80)     0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 8, 8, 80)     0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 8, 8, 480)    0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 8, 8, 480)    0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 8, 8, 480)    0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 8, 8, 80)     320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 8, 8, 80)     0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 8, 8, 80)     0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 8, 8, 480)    0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 8, 8, 480)    0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 8, 8, 480)    0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 8, 8, 80)     320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 8, 8, 80)     0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 8, 8, 80)     0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 8, 8, 480)    0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 8, 8, 480)    0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 8, 8, 480)    0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# block7a_dwconv (DepthwiseConv2D (None, 2, 2, 2304)   20736       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 2, 2, 2304)   9216        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 2, 2, 2304)   0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 2304)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 2304)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 96)     221280      block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 2304)   223488      block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 2, 2, 2304)   0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 2, 2, 640)    1474560     block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 2, 2, 640)    2560        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 2, 2, 3840)   2457600     block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 2, 2, 3840)   15360       block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 2, 2, 3840)   0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 2, 2, 3840)   34560       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 2, 2, 3840)   15360       block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 2, 2, 3840)   0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 3840)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 2, 2, 3840)   0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 2, 2, 640)    2457600     block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 2, 2, 640)    2560        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 2, 2, 640)    0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 2, 2, 640)    0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_expand_conv (Conv2D)    (None, 2, 2, 3840)   2457600     block7b_add[0][0]
# __________________________________________________________________________________________________
# block7c_expand_bn (BatchNormali (None, 2, 2, 3840)   15360       block7c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7c_expand_activation (Acti (None, 2, 2, 3840)   0           block7c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 2, 2, 3840)   34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 2, 2, 3840)   15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 2, 2, 3840)   0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 2, 2, 3840)   0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 2, 2, 640)    2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 2, 2, 640)    2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 2, 2, 640)    0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 2, 2, 640)    0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 2, 2, 3840)   2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 2, 2, 3840)   15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 2, 2, 3840)   0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 2, 2, 3840)   34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 2, 2, 3840)   15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 2, 2, 3840)   0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 2, 2, 3840)   0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 2, 2, 640)    2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 2, 2, 640)    2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (Dropout)          (None, 2, 2, 640)    0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 2, 2, 640)    0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 2, 2, 2560)   1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 2, 2, 2560)   10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 2, 2, 2560)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# flatten_73 (Flatten)            (None, 10240)        0           top_activation[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 256)          2621696     flatten_73[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_39[0][0]
# ==================================================================================================
# Total params: 66,719,640
# Trainable params: 66,408,913
# Non-trainable params: 310,727
# __________________________________________________________________________________________________
# Epoch 1/20
# 19/19 [==============================] - 35s 523ms/step - loss: 0.7714 - accuracy: 0.5063 - val_loss: 0.6919 - val_accuracy: 0.5600
# Epoch 2/20
# 19/19 [==============================] - 5s 251ms/step - loss: 0.7258 - accuracy: 0.5359 - val_loss: 0.6932 - val_accuracy: 0.4867
# Epoch 3/20
# 19/19 [==============================] - 5s 251ms/step - loss: 0.6693 - accuracy: 0.5818 - val_loss: 0.6901 - val_accuracy: 0.5600
# Epoch 4/20
# 19/19 [==============================] - 5s 252ms/step - loss: 0.6302 - accuracy: 0.6609 - val_loss: 0.7018 - val_accuracy: 0.4400
# Epoch 5/20
# 19/19 [==============================] - 5s 248ms/step - loss: 0.6143 - accuracy: 0.6665 - val_loss: 0.7580 - val_accuracy: 0.4400
# Epoch 6/20
# 19/19 [==============================] - 5s 250ms/step - loss: 0.5711 - accuracy: 0.7194 - val_loss: 0.8810 - val_accuracy: 0.4400
# Epoch 7/20
# 19/19 [==============================] - 5s 256ms/step - loss: 0.5286 - accuracy: 0.7601 - val_loss: 0.8566 - val_accuracy: 0.4400
# Epoch 8/20
# 19/19 [==============================] - 5s 253ms/step - loss: 0.5145 - accuracy: 0.7861 - val_loss: 0.7447 - val_accuracy: 0.4400
# Epoch 9/20
# 19/19 [==============================] - 5s 255ms/step - loss: 0.4946 - accuracy: 0.8131 - val_loss: 0.7453 - val_accuracy: 0.4400
# Epoch 10/20
# 19/19 [==============================] - 5s 251ms/step - loss: 0.4748 - accuracy: 0.7988 - val_loss: 0.7454 - val_accuracy: 0.4400
# Epoch 11/20
# 19/19 [==============================] - 5s 252ms/step - loss: 0.4509 - accuracy: 0.8110 - val_loss: 0.7361 - val_accuracy: 0.4400
# Epoch 12/20
# 19/19 [==============================] - 5s 255ms/step - loss: 0.4186 - accuracy: 0.8724 - val_loss: 0.7180 - val_accuracy: 0.4467
# Epoch 13/20
# 19/19 [==============================] - 5s 256ms/step - loss: 0.4217 - accuracy: 0.8697 - val_loss: 0.7152 - val_accuracy: 0.5133
# Epoch 14/20
# 19/19 [==============================] - 5s 253ms/step - loss: 0.3829 - accuracy: 0.8739 - val_loss: 0.6848 - val_accuracy: 0.5933
# Epoch 15/20
# 19/19 [==============================] - 5s 251ms/step - loss: 0.3815 - accuracy: 0.8882 - val_loss: 0.7035 - val_accuracy: 0.5200
# Epoch 16/20
# 19/19 [==============================] - 5s 253ms/step - loss: 0.3765 - accuracy: 0.8775 - val_loss: 0.6952 - val_accuracy: 0.5667
# Epoch 17/20
# 19/19 [==============================] - 5s 253ms/step - loss: 0.3691 - accuracy: 0.8961 - val_loss: 0.6897 - val_accuracy: 0.5667
# Epoch 18/20
# 19/19 [==============================] - 5s 253ms/step - loss: 0.3347 - accuracy: 0.9182 - val_loss: 0.7082 - val_accuracy: 0.5067
# Epoch 19/20
# 19/19 [==============================] - 5s 254ms/step - loss: 0.3102 - accuracy: 0.9211 - val_loss: 0.7213 - val_accuracy: 0.4800
# Epoch 20/20
# 19/19 [==============================] - 5s 255ms/step - loss: 0.3366 - accuracy: 0.8956 - val_loss: 0.7155 - val_accuracy: 0.4933
# 5/5 [==============================] - 0s 65ms/step - loss: 0.7155 - accuracy: 0.4933
# Validation Loss = 0.7155256271362305
# Validation Accuracy = 0.4933333396911621

# %%
test_pretrained_layers_freezing_EfficientNetB(100)
# Out:
# Model: "model_32"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_36 (InputLayer)           [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# rescaling_7 (Rescaling)         (None, 64, 64, 3)    0           input_36[0][0]
# __________________________________________________________________________________________________
# normalization_7 (Normalization) (None, 64, 64, 3)    7           rescaling_7[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 65, 65, 3)    0           normalization_7[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 32, 32, 64)   1728        stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 32, 32, 64)   256         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 32, 32, 64)   0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 32, 32, 64)   576         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 32, 32, 64)   256         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 32, 32, 64)   0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 64)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 64)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 16)     1040        block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 64)     1088        block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 32, 32, 64)   0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 32, 32, 32)   2048        block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 32, 32, 32)   128         block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 32, 32, 32)   128         block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 32, 32, 32)   0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 32)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 32, 32, 32)   0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 32, 32, 32)   128         block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 32, 32, 32)   0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 32, 32, 32)   0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1b_add[0][0]
# __________________________________________________________________________________________________
# block1c_bn (BatchNormalization) (None, 32, 32, 32)   128         block1c_dwconv[0][0]
# __________________________________________________________________________________________________
# block1c_activation (Activation) (None, 32, 32, 32)   0           block1c_bn[0][0]
# __________________________________________________________________________________________________
# block1c_se_squeeze (GlobalAvera (None, 32)           0           block1c_activation[0][0]
# __________________________________________________________________________________________________
# block1c_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1c_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1c_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1c_se_excite (Multiply)    (None, 32, 32, 32)   0           block1c_activation[0][0]
#                                                                  block1c_se_expand[0][0]
# __________________________________________________________________________________________________
# block1c_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1c_se_excite[0][0]
# __________________________________________________________________________________________________
# block1c_project_bn (BatchNormal (None, 32, 32, 32)   128         block1c_project_conv[0][0]
# __________________________________________________________________________________________________
# block1c_drop (Dropout)          (None, 32, 32, 32)   0           block1c_project_bn[0][0]
# __________________________________________________________________________________________________
# block1c_add (Add)               (None, 32, 32, 32)   0           block1c_drop[0][0]
#                                                                  block1b_add[0][0]
# __________________________________________________________________________________________________
# block1d_dwconv (DepthwiseConv2D (None, 32, 32, 32)   288         block1c_add[0][0]
# __________________________________________________________________________________________________
# block1d_bn (BatchNormalization) (None, 32, 32, 32)   128         block1d_dwconv[0][0]
# __________________________________________________________________________________________________
# block1d_activation (Activation) (None, 32, 32, 32)   0           block1d_bn[0][0]
# __________________________________________________________________________________________________
# block1d_se_squeeze (GlobalAvera (None, 32)           0           block1d_activation[0][0]
# __________________________________________________________________________________________________
# block1d_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1d_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1d_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1d_se_excite (Multiply)    (None, 32, 32, 32)   0           block1d_activation[0][0]
#                                                                  block1d_se_expand[0][0]
# __________________________________________________________________________________________________
# block1d_project_conv (Conv2D)   (None, 32, 32, 32)   1024        block1d_se_excite[0][0]
# __________________________________________________________________________________________________
# block1d_project_bn (BatchNormal (None, 32, 32, 32)   128         block1d_project_conv[0][0]
# __________________________________________________________________________________________________
# block1d_drop (Dropout)          (None, 32, 32, 32)   0           block1d_project_bn[0][0]
# __________________________________________________________________________________________________
# block1d_add (Add)               (None, 32, 32, 32)   0           block1d_drop[0][0]
#                                                                  block1c_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 32, 32, 192)  6144        block1d_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 32, 32, 192)  768         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 32, 32, 192)  0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 33, 33, 192)  0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 16, 16, 192)  1728        block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 16, 16, 192)  768         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 16, 16, 192)  0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 192)          0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 192)    0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 8)      1544        block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 192)    1728        block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 16, 16, 192)  0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 16, 16, 48)   9216        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 16, 16, 48)   192         block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 16, 16, 288)  0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 16, 16, 288)  0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 288)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 16, 16, 288)  0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 16, 16, 48)   192         block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 16, 16, 48)   0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 16, 16, 48)   0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 16, 16, 288)  0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 16, 16, 288)  0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 288)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 16, 16, 288)  0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 16, 16, 48)   192         block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 16, 16, 48)   0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 16, 16, 48)   0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2c_add[0][0]
# __________________________________________________________________________________________________
# block2d_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2d_expand_activation (Acti (None, 16, 16, 288)  0           block2d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2d_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2d_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2d_dwconv[0][0]
# __________________________________________________________________________________________________
# block2d_activation (Activation) (None, 16, 16, 288)  0           block2d_bn[0][0]
# __________________________________________________________________________________________________
# block2d_se_squeeze (GlobalAvera (None, 288)          0           block2d_activation[0][0]
# __________________________________________________________________________________________________
# block2d_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2d_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2d_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2d_se_excite (Multiply)    (None, 16, 16, 288)  0           block2d_activation[0][0]
#                                                                  block2d_se_expand[0][0]
# __________________________________________________________________________________________________
# block2d_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2d_se_excite[0][0]
# __________________________________________________________________________________________________
# block2d_project_bn (BatchNormal (None, 16, 16, 48)   192         block2d_project_conv[0][0]
# __________________________________________________________________________________________________
# block2d_drop (Dropout)          (None, 16, 16, 48)   0           block2d_project_bn[0][0]
# __________________________________________________________________________________________________
# block2d_add (Add)               (None, 16, 16, 48)   0           block2d_drop[0][0]
#                                                                  block2c_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2d_add[0][0]
# __________________________________________________________________________________________________
# block2e_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2e_expand_activation (Acti (None, 16, 16, 288)  0           block2e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2e_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2e_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2e_dwconv[0][0]
# __________________________________________________________________________________________________
# block2e_activation (Activation) (None, 16, 16, 288)  0           block2e_bn[0][0]
# __________________________________________________________________________________________________
# block2e_se_squeeze (GlobalAvera (None, 288)          0           block2e_activation[0][0]
# __________________________________________________________________________________________________
# block2e_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2e_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2e_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2e_se_excite (Multiply)    (None, 16, 16, 288)  0           block2e_activation[0][0]
#                                                                  block2e_se_expand[0][0]
# __________________________________________________________________________________________________
# block2e_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2e_se_excite[0][0]
# __________________________________________________________________________________________________
# block2e_project_bn (BatchNormal (None, 16, 16, 48)   192         block2e_project_conv[0][0]
# __________________________________________________________________________________________________
# block2e_drop (Dropout)          (None, 16, 16, 48)   0           block2e_project_bn[0][0]
# __________________________________________________________________________________________________
# block2e_add (Add)               (None, 16, 16, 48)   0           block2e_drop[0][0]
#                                                                  block2d_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2e_add[0][0]
# __________________________________________________________________________________________________
# block2f_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2f_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2f_expand_activation (Acti (None, 16, 16, 288)  0           block2f_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2f_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2f_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2f_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2f_dwconv[0][0]
# __________________________________________________________________________________________________
# block2f_activation (Activation) (None, 16, 16, 288)  0           block2f_bn[0][0]
# __________________________________________________________________________________________________
# block2f_se_squeeze (GlobalAvera (None, 288)          0           block2f_activation[0][0]
# __________________________________________________________________________________________________
# block2f_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2f_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2f_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2f_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2f_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2f_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2f_se_excite (Multiply)    (None, 16, 16, 288)  0           block2f_activation[0][0]
#                                                                  block2f_se_expand[0][0]
# __________________________________________________________________________________________________
# block2f_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2f_se_excite[0][0]
# __________________________________________________________________________________________________
# block2f_project_bn (BatchNormal (None, 16, 16, 48)   192         block2f_project_conv[0][0]
# __________________________________________________________________________________________________
# block2f_drop (Dropout)          (None, 16, 16, 48)   0           block2f_project_bn[0][0]
# __________________________________________________________________________________________________
# block2f_add (Add)               (None, 16, 16, 48)   0           block2f_drop[0][0]
#                                                                  block2e_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2f_add[0][0]
# __________________________________________________________________________________________________
# block2g_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block2g_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2g_expand_activation (Acti (None, 16, 16, 288)  0           block2g_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2g_dwconv (DepthwiseConv2D (None, 16, 16, 288)  2592        block2g_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2g_bn (BatchNormalization) (None, 16, 16, 288)  1152        block2g_dwconv[0][0]
# __________________________________________________________________________________________________
# block2g_activation (Activation) (None, 16, 16, 288)  0           block2g_bn[0][0]
# __________________________________________________________________________________________________
# block2g_se_squeeze (GlobalAvera (None, 288)          0           block2g_activation[0][0]
# __________________________________________________________________________________________________
# block2g_se_reshape (Reshape)    (None, 1, 1, 288)    0           block2g_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2g_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block2g_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2g_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block2g_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2g_se_excite (Multiply)    (None, 16, 16, 288)  0           block2g_activation[0][0]
#                                                                  block2g_se_expand[0][0]
# __________________________________________________________________________________________________
# block2g_project_conv (Conv2D)   (None, 16, 16, 48)   13824       block2g_se_excite[0][0]
# __________________________________________________________________________________________________
# block2g_project_bn (BatchNormal (None, 16, 16, 48)   192         block2g_project_conv[0][0]
# __________________________________________________________________________________________________
# block2g_drop (Dropout)          (None, 16, 16, 48)   0           block2g_project_bn[0][0]
# __________________________________________________________________________________________________
# block2g_add (Add)               (None, 16, 16, 48)   0           block2g_drop[0][0]
#                                                                  block2f_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 16, 16, 288)  13824       block2g_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 16, 16, 288)  1152        block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 16, 16, 288)  0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 19, 19, 288)  0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 8, 8, 288)    7200        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 8, 8, 288)    1152        block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 8, 8, 288)    0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 288)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 8, 8, 288)    0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 8, 8, 80)     23040       block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 8, 8, 80)     320         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 8, 8, 480)    0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 8, 8, 480)    0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 480)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 8, 8, 480)    0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 8, 8, 80)     320         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 8, 8, 80)     0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 8, 8, 80)     0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 8, 8, 480)    0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 8, 8, 480)    0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 480)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 8, 8, 480)    0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 8, 8, 80)     320         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 8, 8, 80)     0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 8, 8, 80)     0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3c_add[0][0]
# __________________________________________________________________________________________________
# block3d_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3d_expand_activation (Acti (None, 8, 8, 480)    0           block3d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3d_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3d_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3d_dwconv[0][0]
# __________________________________________________________________________________________________
# block3d_activation (Activation) (None, 8, 8, 480)    0           block3d_bn[0][0]
# __________________________________________________________________________________________________
# block3d_se_squeeze (GlobalAvera (None, 480)          0           block3d_activation[0][0]
# __________________________________________________________________________________________________
# block3d_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3d_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3d_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3d_se_excite (Multiply)    (None, 8, 8, 480)    0           block3d_activation[0][0]
#                                                                  block3d_se_expand[0][0]
# __________________________________________________________________________________________________
# block3d_project_conv (Conv2D)   (None, 8, 8, 80)     38400       block3d_se_excite[0][0]
# __________________________________________________________________________________________________
# block3d_project_bn (BatchNormal (None, 8, 8, 80)     320         block3d_project_conv[0][0]
# __________________________________________________________________________________________________
# block3d_drop (Dropout)          (None, 8, 8, 80)     0           block3d_project_bn[0][0]
# __________________________________________________________________________________________________
# block3d_add (Add)               (None, 8, 8, 80)     0           block3d_drop[0][0]
#                                                                  block3c_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_conv (Conv2D)    (None, 8, 8, 480)    38400       block3d_add[0][0]
# __________________________________________________________________________________________________
# block3e_expand_bn (BatchNormali (None, 8, 8, 480)    1920        block3e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3e_expand_activation (Acti (None, 8, 8, 480)    0           block3e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3e_dwconv (DepthwiseConv2D (None, 8, 8, 480)    12000       block3e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3e_bn (BatchNormalization) (None, 8, 8, 480)    1920        block3e_dwconv[0][0]
# __________________________________________________________________________________________________
# block3e_activation (Activation) (None, 8, 8, 480)    0           block3e_bn[0][0]
# __________________________________________________________________________________________________
# block3e_se_squeeze (GlobalAvera (None, 480)          0           block3e_activation[0][0]
# __________________________________________________________________________________________________
# block3e_se_reshape (Reshape)    (None, 1, 1, 480)    0           block3e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3e_se_reduce (Conv2D)      (None, 1, 1, 20)     9620        block3e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3e_se_expand (Conv2D)      (None, 1, 1, 480)    10080       block3e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3e_se_excite (Multiply)    (None, 8, 8, 480)    0           block3e_activation[0][0]
#                                                                  block3e_se_expand[0][0]
# ...
# __________________________________________________________________________________________________
# block7c_dwconv (DepthwiseConv2D (None, 2, 2, 3840)   34560       block7c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7c_bn (BatchNormalization) (None, 2, 2, 3840)   15360       block7c_dwconv[0][0]
# __________________________________________________________________________________________________
# block7c_activation (Activation) (None, 2, 2, 3840)   0           block7c_bn[0][0]
# __________________________________________________________________________________________________
# block7c_se_squeeze (GlobalAvera (None, 3840)         0           block7c_activation[0][0]
# __________________________________________________________________________________________________
# block7c_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7c_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7c_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7c_se_excite (Multiply)    (None, 2, 2, 3840)   0           block7c_activation[0][0]
#                                                                  block7c_se_expand[0][0]
# __________________________________________________________________________________________________
# block7c_project_conv (Conv2D)   (None, 2, 2, 640)    2457600     block7c_se_excite[0][0]
# __________________________________________________________________________________________________
# block7c_project_bn (BatchNormal (None, 2, 2, 640)    2560        block7c_project_conv[0][0]
# __________________________________________________________________________________________________
# block7c_drop (Dropout)          (None, 2, 2, 640)    0           block7c_project_bn[0][0]
# __________________________________________________________________________________________________
# block7c_add (Add)               (None, 2, 2, 640)    0           block7c_drop[0][0]
#                                                                  block7b_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_conv (Conv2D)    (None, 2, 2, 3840)   2457600     block7c_add[0][0]
# __________________________________________________________________________________________________
# block7d_expand_bn (BatchNormali (None, 2, 2, 3840)   15360       block7d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7d_expand_activation (Acti (None, 2, 2, 3840)   0           block7d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7d_dwconv (DepthwiseConv2D (None, 2, 2, 3840)   34560       block7d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7d_bn (BatchNormalization) (None, 2, 2, 3840)   15360       block7d_dwconv[0][0]
# __________________________________________________________________________________________________
# block7d_activation (Activation) (None, 2, 2, 3840)   0           block7d_bn[0][0]
# __________________________________________________________________________________________________
# block7d_se_squeeze (GlobalAvera (None, 3840)         0           block7d_activation[0][0]
# __________________________________________________________________________________________________
# block7d_se_reshape (Reshape)    (None, 1, 1, 3840)   0           block7d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7d_se_reduce (Conv2D)      (None, 1, 1, 160)    614560      block7d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7d_se_expand (Conv2D)      (None, 1, 1, 3840)   618240      block7d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7d_se_excite (Multiply)    (None, 2, 2, 3840)   0           block7d_activation[0][0]
#                                                                  block7d_se_expand[0][0]
# __________________________________________________________________________________________________
# block7d_project_conv (Conv2D)   (None, 2, 2, 640)    2457600     block7d_se_excite[0][0]
# __________________________________________________________________________________________________
# block7d_project_bn (BatchNormal (None, 2, 2, 640)    2560        block7d_project_conv[0][0]
# __________________________________________________________________________________________________
# block7d_drop (Dropout)          (None, 2, 2, 640)    0           block7d_project_bn[0][0]
# __________________________________________________________________________________________________
# block7d_add (Add)               (None, 2, 2, 640)    0           block7d_drop[0][0]
#                                                                  block7c_add[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 2, 2, 2560)   1638400     block7d_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 2, 2, 2560)   10240       top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 2, 2, 2560)   0           top_bn[0][0]
# __________________________________________________________________________________________________
# flatten_35 (Flatten)            (None, 10240)        0           top_activation[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 256)          2621696     flatten_35[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 1)            257         dense_31[0][0]
# ==================================================================================================
# Total params: 66,719,640
# Trainable params: 66,406,353
# Non-trainable params: 313,287
# __________________________________________________________________________________________________
# Epoch 1/60
# 19/19 [==============================] - 34s 481ms/step - loss: 0.7119 - accuracy: 0.5155 - val_loss: 0.7160 - val_accuracy: 0.4400
# Epoch 2/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.6687 - accuracy: 0.5884 - val_loss: 0.7138 - val_accuracy: 0.4400
# Epoch 3/60
# 19/19 [==============================] - 5s 248ms/step - loss: 0.6652 - accuracy: 0.6034 - val_loss: 0.7279 - val_accuracy: 0.4400
# Epoch 4/60
# 19/19 [==============================] - 5s 248ms/step - loss: 0.1302 - accuracy: 0.9534 - val_loss: 0.4564 - val_accuracy: 0.8267
# Epoch 44/60
# 19/19 [==============================] - 5s 245ms/step - loss: 0.1485 - accuracy: 0.9562 - val_loss: 0.1810 - val_accuracy: 0.9333
# Epoch 45/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.1229 - accuracy: 0.9555 - val_loss: 0.2429 - val_accuracy: 0.9067
# Epoch 46/60
# 19/19 [==============================] - 5s 248ms/step - loss: 0.1085 - accuracy: 0.9723 - val_loss: 0.6034 - val_accuracy: 0.7933
# Epoch 47/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.1164 - accuracy: 0.9697 - val_loss: 0.7817 - val_accuracy: 0.7067
# Epoch 48/60
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0881 - accuracy: 0.9818 - val_loss: 0.5876 - val_accuracy: 0.7600
# Epoch 49/60
# 19/19 [==============================] - 5s 249ms/step - loss: 0.1291 - accuracy: 0.9624 - val_loss: 0.3192 - val_accuracy: 0.8867
# Epoch 50/60
# 19/19 [==============================] - 5s 249ms/step - loss: 0.1552 - accuracy: 0.9596 - val_loss: 0.5519 - val_accuracy: 0.8333
# Epoch 51/60
# 19/19 [==============================] - 5s 252ms/step - loss: 0.1164 - accuracy: 0.9662 - val_loss: 0.7257 - val_accuracy: 0.7533
# Epoch 52/60
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.3745 - val_accuracy: 0.8267
# Epoch 53/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.0704 - accuracy: 0.9770 - val_loss: 0.2883 - val_accuracy: 0.8733
# Epoch 54/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.0931 - accuracy: 0.9745 - val_loss: 0.2312 - val_accuracy: 0.9067
# Epoch 55/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.1274 - accuracy: 0.9516 - val_loss: 0.5719 - val_accuracy: 0.7667
# Epoch 56/60
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0919 - accuracy: 0.9683 - val_loss: 1.1398 - val_accuracy: 0.6200
# Epoch 57/60
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0872 - accuracy: 0.9731 - val_loss: 0.3876 - val_accuracy: 0.8333
# Epoch 58/60
# 19/19 [==============================] - 5s 246ms/step - loss: 0.1172 - accuracy: 0.9646 - val_loss: 0.7819 - val_accuracy: 0.6600
# Epoch 59/60
# 19/19 [==============================] - 5s 247ms/step - loss: 0.1096 - accuracy: 0.9540 - val_loss: 0.5873 - val_accuracy: 0.7667
# Epoch 60/60
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0745 - accuracy: 0.9726 - val_loss: 0.4910 - val_accuracy: 0.8000
# 5/5 [==============================] - 0s 63ms/step - loss: 0.4910 - accuracy: 0.8000
# Validation Loss = 0.49097752571105957
# Validation Accuracy = 0.800000011920929

# %% [markdown]
# ## 3.3 Conclusion

# %% [markdown]
# That's it! Congratulations on training CNN use cases models.
#
# Make sure you deliver all the requirements for the submission.
